# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Divers

# %%
drivers = pd.read_csv('../data/Barber Motorsports Park/GR_Driver_Championship.csv', delimiter=';')
drivers.head()
# Out:
#    Pos       Participant  Points  Number    NAME     SURNAME COUNTRY  \
# 0    1    Westin Workman     224      13  Westin     Workman     USA
# 1    2        Jaxon Bell     141       7   Jaxon        Bell     USA
# 2    3     Ethan Goulart     126      72   Ethan     Goulart     USA
# 3    4  Lucas Weisenberg     124      46   Lucas  Weisenberg     USA
# 4    5  Spike Kohlbecker     112      55   Spike  Kohlbecker     USA
#
#                                           TEAM         MANUFACTURER CLASS  \
# 0                                   BSI Racing  Toyota Gazoo Racing    Am
# 1                         Copeland Motorsports  Toyota Gazoo Racing    Am
# 2                                    TechSport  Toyota Gazoo Racing    Am
# 3                                 Lucas Racing  Toyota Gazoo Racing    Am
# 4  RVA Graphics Motorsports by Speed Syndicate  Toyota Gazoo Racing    Am
#
#    ... Indy_Race 2_Extra 2  Indy_Race 2_TotalExtraPoints  Indy_Race 2_Status  \
# ...

# %% [markdown]
# ## Teams

# %%
Teams = pd.read_csv('../data/Barber Motorsports Park/GR_Teams_Championship.csv', delimiter=';')
Teams.head()
# Out:
#    Pos                                  Participant  Points  \
# 0    1                                   BSI Racing     228
# 1    2                         Copeland Motorsports     192
# 2    3  RVA Graphics Motorsports by Speed Syndicate     182
# 3    4                                    TechSport     177
# 4    5                                 Lucas Racing     147
#
#    Sonoma Raceway_Race 1_Points  Sonoma Raceway_Race 1_PolePoints  \
# 0                          18.0                                 0
# 1                          12.0                                 0
# 2                          15.0                                 0
# 3                          10.0                                 0
# 4                          25.0                                 0
#
#    Sonoma Raceway_Race 1_FastestLapPoints  Sonoma Raceway_Race 1_Extra 1  \
# 0                                       0                              0
# ...

# %% [markdown]
# ## Provisional results (R1 & R2)

# %%
prov_rc_rs_1 = pd.read_csv('../data/Barber Motorsports Park/RACE 1/05_Provisional_Results_by_Class_Race_1.csv', delimiter=';')
prov_rc_rs_1.head()
# Out:
#   CLASS_TYPE  POS  PIC  NUMBER                                         TEAM  \
# 0         Am    1    1      13                                   BSI Racing
# 1         Am    2    2      22                         Copeland Motorsports
# 2         Am    3    3      72                                    TechSport
# 3         Am    4    4      55  RVA Graphics Motorsports by Speed Syndicate
# 4         Am    5    5       2  RVA Graphics Motorsports by Speed Syndicate
#
#        VEHICLE            DRIVER  LAPS    ELAPSED GAP_FIRST GAP_PREVIOUS  \
# 0  Toyota GR86    Westin Workman    27  45:15.035       NaN          NaN
# 1  Toyota GR86   Jeremy Fletcher    27  45:17.775    +2.740       +2.740
# 2  Toyota GR86     Ethan Goulart    27  45:25.690   +10.655       +7.915
# 3  Toyota GR86  Spike Kohlbecker    27  45:26.144   +11.109       +0.454
# 4  Toyota GR86      Will Robusto    27  45:29.124   +14.089       +2.980
#
#    BEST_LAP_NUM BEST_LAP_TIME  BEST_LAP_KPH  Unnamed: 14
# ...

# %%
prov_rc_rs_2 = pd.read_csv('../data/Barber Motorsports Park/RACE 2/05_Provisional_Results_by_Class_Race_2.csv', delimiter=';')
prov_rc_rs_2.head()
# Out:
#   CLASS_TYPE  POS  PIC  NUMBER                                         TEAM  \
# 0         Am    1    1      13                                   BSI Racing
# 1         Am    2    2      22                         Copeland Motorsports
# 2         Am    3    3       2  RVA Graphics Motorsports by Speed Syndicate
# 3         Am    4    4      72                                    TechSport
# 4         Am    5    5      46                                 Lucas Racing
#
#        VEHICLE            DRIVER  LAPS    ELAPSED GAP_FIRST GAP_PREVIOUS  \
# 0  Toyota GR86    Westin Workman    28  45:37.014       NaN          NaN
# 1  Toyota GR86   Jeremy Fletcher    28  45:37.248    +0.234       +0.234
# 2  Toyota GR86      Will Robusto    28  45:53.320   +16.306      +16.072
# 3  Toyota GR86     Ethan Goulart    28  45:57.708   +20.694       +4.388
# 4  Toyota GR86  Lucas Weisenberg    28  45:57.899   +20.885       +0.191
#
#    BEST_LAP_NUM BEST_LAP_TIME  BEST_LAP_KPH  Unnamed: 14
# ...

# %%
rs_r1 = pd.read_csv('../data/Barber Motorsports Park/RACE 1/05_Results_by_Class_GR_Cup_Race_1_Official.csv', delimiter=';')
rs_r1.head()
# Out:
#   CLASS_TYPE  POS  PIC  NUMBER                                         TEAM  \
# 0         Am    1    1      13                                   BSI Racing
# 1         Am    2    2      22                         Copeland Motorsports
# 2         Am    3    3      72                                    TechSport
# 3         Am    4    4      55  RVA Graphics Motorsports by Speed Syndicate
# 4         Am    5    5       2  RVA Graphics Motorsports by Speed Syndicate
#
#        VEHICLE            DRIVER  LAPS    ELAPSED GAP_FIRST GAP_PREVIOUS  \
# 0  Toyota GR86    Westin Workman    27  45:15.035       NaN          NaN
# 1  Toyota GR86   Jeremy Fletcher    27  45:17.775    +2.740       +2.740
# 2  Toyota GR86     Ethan Goulart    27  45:25.690   +10.655       +7.915
# 3  Toyota GR86  Spike Kohlbecker    27  45:26.144   +11.109       +0.454
# 4  Toyota GR86      Will Robusto    27  45:29.124   +14.089       +2.980
#
#    BEST_LAP_NUM BEST_LAP_TIME  BEST_LAP_KPH  Unnamed: 14
# ...

# %%
rs_r2 = pd.read_csv('../data/Barber Motorsports Park/RACE 2/05_Results_by_Class_GR_Cup_Race_2_Official.csv', delimiter=';')
rs_r2.head()
# Out:
#   CLASS_TYPE  POS  PIC  NUMBER                                         TEAM  \
# 0         Am    1    1      13                                   BSI Racing
# 1         Am    2    2      22                         Copeland Motorsports
# 2         Am    3    3       2  RVA Graphics Motorsports by Speed Syndicate
# 3         Am    4    4      72                                    TechSport
# 4         Am    5    5      46                                 Lucas Racing
#
#        VEHICLE            DRIVER  LAPS    ELAPSED GAP_FIRST GAP_PREVIOUS  \
# 0  Toyota GR86    Westin Workman    28  45:37.014       NaN          NaN
# 1  Toyota GR86   Jeremy Fletcher    28  45:37.248    +0.234       +0.234
# 2  Toyota GR86      Will Robusto    28  45:53.320   +16.306      +16.072
# 3  Toyota GR86     Ethan Goulart    28  45:57.708   +20.694       +4.388
# 4  Toyota GR86  Lucas Weisenberg    28  45:57.899   +20.885       +0.191
#
#    BEST_LAP_NUM BEST_LAP_TIME  BEST_LAP_KPH  Unnamed: 14
# ...

# %% [markdown]
# ## Weather

# %%
weat_rc_1 = pd.read_csv('../data/Barber Motorsports Park/RACE 1/26_Weather_Race_1.csv', delimiter=';')
weat_rc_1.head()
# Out:
#    TIME_UTC_SECONDS         TIME_UTC_STR  AIR_TEMP  TRACK_TEMP  HUMIDITY  \
# 0        1757184078  9/6/2025 6:41:18 PM     29.80           0     56.75
# 1        1757184141  9/6/2025 6:42:21 PM     29.87           0     57.23
# 2        1757184204  9/6/2025 6:43:24 PM     29.79           0     57.05
# 3        1757184266  9/6/2025 6:44:26 PM     29.75           0     57.42
# 4        1757184329  9/6/2025 6:45:29 PM     29.78           0     56.75
#
#    PRESSURE  WIND_SPEED  WIND_DIRECTION  RAIN  Unnamed: 9
# 0     992.9        2.88             342     0         NaN
# 1     993.0        5.04             280     0         NaN
# 2     993.0        4.68              30     0         NaN
# 3     992.9        3.96              11     0         NaN
# 4     992.8       10.44             299     0         NaN

# %%
weat_rc_2 = pd.read_csv('../data/Barber Motorsports Park/RACE 2/26_Weather_Race_2.csv', delimiter=';')
weat_rc_2.head()
# Out:
#    TIME_UTC_SECONDS         TIME_UTC_STR  AIR_TEMP  TRACK_TEMP  HUMIDITY  \
# 0        1757257552  9/7/2025 3:05:52 PM     23.54           0     49.28
# 1        1757257614  9/7/2025 3:06:54 PM     23.67           0     49.50
# 2        1757257677  9/7/2025 3:07:57 PM     23.72           0     49.27
# 3        1757257740  9/7/2025 3:09:00 PM     23.71           0     49.56
# 4        1757257802  9/7/2025 3:10:02 PM     23.72           0     49.23
#
#    PRESSURE  WIND_SPEED  WIND_DIRECTION  RAIN  Unnamed: 9
# 0     995.1        5.04             348     0         NaN
# 1     995.1        7.92             350     0         NaN
# 2     995.1        5.76             331     0         NaN
# 3     995.2        1.44              24     0         NaN
# 4     995.2        6.48             335     0         NaN

# %% [markdown]
# ## Analysis

# %%
an_rc_1 = pd.read_csv('../data/Barber Motorsports Park/RACE 1/23_AnalysisEnduranceWithSections_Race_1.csv', delimiter=';')
an_rc_1.head()
# Out:
#    NUMBER   DRIVER_NUMBER   LAP_NUMBER  LAP_TIME   LAP_IMPROVEMENT  \
# 0       3               1            1  1:54.168                 0
# 1       3               1            2  2:13.691                 0
# 2       3               1            3  1:58.021                 0
# 3       3               1            4  1:40.861                 0
# 4       3               1            5  1:39.725                 0
#
#    CROSSING_FINISH_LINE_IN_PIT      S1   S1_IMPROVEMENT      S2  \
# 0                          NaN  33.413                0  43.534
# 1                          NaN  39.570                0  57.345
# 2                          NaN  33.801                0  49.853
# 3                          NaN  27.568                0  43.834
# 4                          NaN  27.214                0  43.389
#
#     S2_IMPROVEMENT  ... IM1_elapsed  IM2a_time  IM2a_elapsed IM2_time  \
# 0                0  ...      33.413     30.646      1:04.059   12.888
# ...

# %%
an_rc_2 = pd.read_csv('../data/Barber Motorsports Park/RACE 2/23_AnalysisEnduranceWithSections_Race_2.csv', delimiter=';')
an_rc_2.head()
# Out:
#    NUMBER   DRIVER_NUMBER   LAP_NUMBER  LAP_TIME   LAP_IMPROVEMENT  \
# 0       3               1            1  1:45.342                 0
# 1       3               1            2  1:39.505                 0
# 2       3               1            3  1:39.249                 0
# 3       3               1            4  1:39.640                 0
# 4       3               1            5  1:39.275                 0
#
#    CROSSING_FINISH_LINE_IN_PIT      S1   S1_IMPROVEMENT      S2  \
# 0                          NaN  31.243                0  44.136
# 1                          NaN  27.260                0  43.038
# 2                          NaN  27.164                0  42.982
# 3                          NaN  26.972                0  43.276
# 4                          NaN  26.999                0  43.309
#
#     S2_IMPROVEMENT  ... IM1_elapsed  IM2a_time  IM2a_elapsed IM2_time  \
# 0                0  ...      31.243     31.093      1:02.336   13.043
# ...
