# %% [markdown]
# ## Libraries

# %%
import os
import time
import requests
import pandas as pd
import numpy as np
from collections import defaultdict
from pathlib import Path

# %% [markdown]
# ### Structuring file Data

# %%
data = defaultdict(list)
current_track = None

with open("./output/raw_csv_links.csv", "r", encoding="utf-8") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue

        if line.startswith("http"):
            data[current_track].append(line)
        else:
            current_track = line

# %% [markdown]
# ### Converting to DF

# %%
df = pd.DataFrame(dict(
    [(k, pd.Series(v)) for k, v in data.items()]
))
df.head()
# Out:
#                                       Sonoma Raceway  \
# 0  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 1  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 2  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 3  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 4  http://usac.alkamelna.com/Results/06_SRO/25_20...
#
#                            Long Beach Street Circuit  \
# 0  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 1  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 2  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 3  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 4  http://usac.alkamelna.com/Results/06_SRO/25_20...
#
#                              Circuit of the Americas  \
# 0  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 1  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 2  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 3  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 4  http://usac.alkamelna.com/Results/06_SRO/25_20...
#
#                        Sebring International Raceway  \
# 0  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 1  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 2  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 3  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 4  http://usac.alkamelna.com/Results/06_SRO/25_20...
#
#                       VIRginia International Raceway  \
# 0  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 1  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 2  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 3  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 4  http://usac.alkamelna.com/Results/06_SRO/25_20...
#
#                                         Road America  \
# 0  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 1  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 2  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 3  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 4  http://usac.alkamelna.com/Results/06_SRO/25_20...
#
#                              Barber Motorsports Park  \
# 0  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 1  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 2  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 3  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 4  http://usac.alkamelna.com/Results/06_SRO/25_20...
#
#                       Indianapolis Motor Speedway RC
# 0  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 1  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 2  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 3  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 4  http://usac.alkamelna.com/Results/06_SRO/25_20...

# %% [markdown]
# ### Filtering Data

# %%
Season = 'SRO'
Year = '2025'
Races = ('Race 1','Race 2')
RaceEvent = 'TGRNA GR CUP NORTH AMERICA'

# %%
def match_url(x):
    if not isinstance(x, str):
        return False

    x_list = x.replace('%20', ' ').split('/')

    if len(x_list) < 8:
        return False

    return (
        Season.lower() in x_list[4].lower()
        and Year in x_list[5]
        and RaceEvent.lower() in x_list[7].lower()
        and any(k.lower() in x_list[-2].lower() for k in Races)
    )

# %%
matched = dict()
for column in df.columns:
    current_column = df[column]
    mask = current_column.apply(match_url)
    matched[column] = current_column[mask]

filtered_df = pd.DataFrame(dict(
    [(k, pd.Series(v)) for k, v in matched.items()]
))

# %%
filtered_df.head()
# Out:
#    Sonoma Raceway Long Beach Street Circuit Circuit of the Americas  \
# 30            NaN                       NaN                     NaN
# 31            NaN                       NaN                     NaN
# 32            NaN                       NaN                     NaN
# 33            NaN                       NaN                     NaN
# 34            NaN                       NaN                     NaN
#
#    Sebring International Raceway VIRginia International Raceway Road America  \
# 30                           NaN                            NaN          NaN
# 31                           NaN                            NaN          NaN
# 32                           NaN                            NaN          NaN
# 33                           NaN                            NaN          NaN
# 34                           NaN                            NaN          NaN
#
#    Barber Motorsports Park                     Indianapolis Motor Speedway RC
# 30                     NaN  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 31                     NaN  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 32                     NaN  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 33                     NaN  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 34                     NaN  http://usac.alkamelna.com/Results/06_SRO/25_20...

# %%
filtered_df['Sonoma Raceway'].notnull().sum()
# Out:
# np.int64(12)

# %% [markdown]
# ### Saving Filtered Links

# %%
filtered_df.to_csv('./output/all_csv_links.csv',index = False)

# %% [markdown]
# ### Downloading Data

# %%
df = pd.read_csv('./output/all_csv_links.csv')
df.head()
# Out:
#   Sonoma Raceway  Long Beach Street Circuit Circuit of the Americas  \
# 0            NaN                        NaN                     NaN
# 1            NaN                        NaN                     NaN
# 2            NaN                        NaN                     NaN
# 3            NaN                        NaN                     NaN
# 4            NaN                        NaN                     NaN
#
#   Sebring International Raceway VIRginia International Raceway Road America  \
# 0                           NaN                            NaN          NaN
# 1                           NaN                            NaN          NaN
# 2                           NaN                            NaN          NaN
# 3                           NaN                            NaN          NaN
# 4                           NaN                            NaN          NaN
#
#   Barber Motorsports Park                     Indianapolis Motor Speedway RC
# 0                     NaN  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 1                     NaN  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 2                     NaN  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 3                     NaN  http://usac.alkamelna.com/Results/06_SRO/25_20...
# 4                     NaN  http://usac.alkamelna.com/Results/06_SRO/25_20...

# %%
BASE_PATH = Path('../data/')

# %%
def download_file(url, out_dir="new_event"):
    if not isinstance(url, str):
        return None

    url_lower = url.lower()

    # Determine the race from the URL
    if "race 1" in url_lower or "race%201" in url_lower:
        race_folder = "RACE 1"
    elif "race 2" in url_lower or "race%202" in url_lower:
        race_folder = "RACE 2"
    else:
        race_folder = "UNKNOWN_RACE"  # fallback (optional)

    # Create the full path: BASE_PATH / out_dir / race_folder
    target_dir = BASE_PATH / out_dir / race_folder
    target_dir.mkdir(parents=True, exist_ok=True)

    # Use the original filename
    filename = url.split("/")[-1]
    file_path = target_dir / filename

    try:
        r = requests.get(url, timeout=30)
        r.raise_for_status()

        # Write file to disk
        file_path.write_bytes(r.content)

        print("fileurl:", url)
        return str(file_path)

    except Exception as e:
        print(f"Failed: {url} → {e}")
        return None

# %%
for column in df.columns:
    if column != 'Sonoma Raceway':
        df[column].apply(lambda url: download_file(url,out_dir = column))
# Out:
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/03_Circuit%20of%20the%20Americas/17_TGRNA%20GR%20Cup%20North%20America/202504261555_Race%201/00_Results%20GR%20Cup%20Race%201%20Official.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/03_Circuit%20of%20the%20Americas/17_TGRNA%20GR%20Cup%20North%20America/202504261555_Race%201/03_Provisional%20Results_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/03_Circuit%20of%20the%20Americas/17_TGRNA%20GR%20Cup%20North%20America/202504261555_Race%201/05_Provisional%20Results%20by%20Class_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/03_Circuit%20of%20the%20Americas/17_TGRNA%20GR%20Cup%20North%20America/202504261555_Race%201/23_AnalysisEnduranceWithSections_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/03_Circuit%20of%20the%20Americas/17_TGRNA%20GR%20Cup%20North%20America/202504261555_Race%201/26_Weather_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/03_Circuit%20of%20the%20Americas/17_TGRNA%20GR%20Cup%20North%20America/202504261555_Race%201/99_Best%2010%20Laps%20By%20Driver_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/03_Circuit%20of%20the%20Americas/17_TGRNA%20GR%20Cup%20North%20America/202504271215_%20Race%202/03_Provisional%20Results_%20Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/03_Circuit%20of%20the%20Americas/17_TGRNA%20GR%20Cup%20North%20America/202504271215_%20Race%202/05_Provisional%20Results%20by%20Class_%20Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/03_Circuit%20of%20the%20Americas/17_TGRNA%20GR%20Cup%20North%20America/202504271215_%20Race%202/23_AnalysisEnduranceWithSections_%20Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/03_Circuit%20of%20the%20Americas/17_TGRNA%20GR%20Cup%20North%20America/202504271215_%20Race%202/26_Weather_%20Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/03_Circuit%20of%20the%20Americas/17_TGRNA%20GR%20Cup%20North%20America/202504271215_%20Race%202/99_Best%2010%20Laps%20By%20Driver_%20Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/03_Circuit%20of%20the%20Americas/17_TGRNA%20GR%20Cup%20North%20America/202504271215_%20Race%202/GR%20Drivers%20Championship.csv
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/03_Circuit%20of%20the%20Americas/17_TGRNA%20GR%20Cup%20North%20America/202504271215_%20Race%202/GR%20Teams%20Championship.csv
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/04_Sebring%20International%20Raceway/22_TGRNA%20GR%20Cup%20North%20America/202505171340_Race%201/00_Results%20GR%20Race%201%20Official.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/04_Sebring%20International%20Raceway/22_TGRNA%20GR%20Cup%20North%20America/202505171340_Race%201/03_Provisional%20Results_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/04_Sebring%20International%20Raceway/22_TGRNA%20GR%20Cup%20North%20America/202505171340_Race%201/05_Provisional%20Results%20by%20Class_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/04_Sebring%20International%20Raceway/22_TGRNA%20GR%20Cup%20North%20America/202505171340_Race%201/23_AnalysisEnduranceWithSections_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/04_Sebring%20International%20Raceway/22_TGRNA%20GR%20Cup%20North%20America/202505171340_Race%201/26_Weather_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/04_Sebring%20International%20Raceway/22_TGRNA%20GR%20Cup%20North%20America/202505171340_Race%201/99_Best%2010%20Laps%20By%20Driver_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/04_Sebring%20International%20Raceway/22_TGRNA%20GR%20Cup%20North%20America/202505181005_Race%202/00_Results%20GR%20Race%202%20Official.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/04_Sebring%20International%20Raceway/22_TGRNA%20GR%20Cup%20North%20America/202505181005_Race%202/03_Provisional%20Results_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/04_Sebring%20International%20Raceway/22_TGRNA%20GR%20Cup%20North%20America/202505181005_Race%202/05_Provisional%20Results%20by%20Class_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/04_Sebring%20International%20Raceway/22_TGRNA%20GR%20Cup%20North%20America/202505181005_Race%202/23_AnalysisEnduranceWithSections_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/04_Sebring%20International%20Raceway/22_TGRNA%20GR%20Cup%20North%20America/202505181005_Race%202/26_Weather_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/04_Sebring%20International%20Raceway/22_TGRNA%20GR%20Cup%20North%20America/202505181005_Race%202/99_Best%2010%20Laps%20By%20Driver_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/05_VIRginia%20International%20Raceway/31_TGRNA%20GR%20Cup%20North%20America/202507191405_Race%201/03_Provisional%20Results_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/05_VIRginia%20International%20Raceway/31_TGRNA%20GR%20Cup%20North%20America/202507191405_Race%201/03_Results%20GR%20Cup%20Race%201%20Official.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/05_VIRginia%20International%20Raceway/31_TGRNA%20GR%20Cup%20North%20America/202507191405_Race%201/05_Provisional%20Results%20by%20Class_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/05_VIRginia%20International%20Raceway/31_TGRNA%20GR%20Cup%20North%20America/202507191405_Race%201/05_Results%20by%20Class%20GR%20Cup%20Race%201%20Official.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/05_VIRginia%20International%20Raceway/31_TGRNA%20GR%20Cup%20North%20America/202507191405_Race%201/23_AnalysisEnduranceWithSections_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/05_VIRginia%20International%20Raceway/31_TGRNA%20GR%20Cup%20North%20America/202507191405_Race%201/26_Weather_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/05_VIRginia%20International%20Raceway/31_TGRNA%20GR%20Cup%20North%20America/202507191405_Race%201/99_Best%2010%20Laps%20By%20Driver_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/05_VIRginia%20International%20Raceway/31_TGRNA%20GR%20Cup%20North%20America/202507201245_Race%202/03_Provisional%20Results_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/05_VIRginia%20International%20Raceway/31_TGRNA%20GR%20Cup%20North%20America/202507201245_Race%202/03_Results%20GR%20Cup%20Race%202%20Official.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/05_VIRginia%20International%20Raceway/31_TGRNA%20GR%20Cup%20North%20America/202507201245_Race%202/05_Provisional%20Results%20by%20Class_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/05_VIRginia%20International%20Raceway/31_TGRNA%20GR%20Cup%20North%20America/202507201245_Race%202/05_Results%20by%20Class%20GR%20Cup%20Race%202%20Official.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/05_VIRginia%20International%20Raceway/31_TGRNA%20GR%20Cup%20North%20America/202507201245_Race%202/23_AnalysisEnduranceWithSections_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/05_VIRginia%20International%20Raceway/31_TGRNA%20GR%20Cup%20North%20America/202507201245_Race%202/26_Weather_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/05_VIRginia%20International%20Raceway/31_TGRNA%20GR%20Cup%20North%20America/202507201245_Race%202/99_Best%2010%20Laps%20By%20Driver_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/05_VIRginia%20International%20Raceway/31_TGRNA%20GR%20Cup%20North%20America/202507201245_Race%202/GR%20Drivers%20Championship.csv
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/05_VIRginia%20International%20Raceway/31_TGRNA%20GR%20Cup%20North%20America/202507201245_Race%202/GR%20Teams%20Championship.csv
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/06_Road%20America/40_TGRNA%20GR%20Cup%20North%20America/202508161423_Race%201/03_Provisional%20Results_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/06_Road%20America/40_TGRNA%20GR%20Cup%20North%20America/202508161423_Race%201/03_Results%20GR%20Cup%20Race%201%20Official-1.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/06_Road%20America/40_TGRNA%20GR%20Cup%20North%20America/202508161423_Race%201/05_Provisional%20Results%20by%20Class_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/06_Road%20America/40_TGRNA%20GR%20Cup%20North%20America/202508161423_Race%201/05_Results%20by%20Class%20GR%20Cup%20Race%201%20Official.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/06_Road%20America/40_TGRNA%20GR%20Cup%20North%20America/202508161423_Race%201/23_AnalysisEnduranceWithSections_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/06_Road%20America/40_TGRNA%20GR%20Cup%20North%20America/202508161423_Race%201/26_Weather_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/06_Road%20America/40_TGRNA%20GR%20Cup%20North%20America/202508161423_Race%201/99_Best%2010%20Laps%20By%20Driver_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/06_Road%20America/40_TGRNA%20GR%20Cup%20North%20America/202508171245_Race%202/03_Provisional%20Results_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/06_Road%20America/40_TGRNA%20GR%20Cup%20North%20America/202508171245_Race%202/03_Results%20GR%20Cup%20Race%202%20Official.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/06_Road%20America/40_TGRNA%20GR%20Cup%20North%20America/202508171245_Race%202/05_Provisional%20Results%20by%20Class_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/06_Road%20America/40_TGRNA%20GR%20Cup%20North%20America/202508171245_Race%202/05_Results%20by%20Class%20GR%20Cup%20Race%202%20Official.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/06_Road%20America/40_TGRNA%20GR%20Cup%20North%20America/202508171245_Race%202/23_AnalysisEnduranceWithSections_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/06_Road%20America/40_TGRNA%20GR%20Cup%20North%20America/202508171245_Race%202/26_Weather_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/06_Road%20America/40_TGRNA%20GR%20Cup%20North%20America/202508171245_Race%202/99_Best%2010%20Laps%20By%20Driver_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/06_Road%20America/40_TGRNA%20GR%20Cup%20North%20America/202508171245_Race%202/GR%20Drivers%20Championship.csv
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/06_Road%20America/40_TGRNA%20GR%20Cup%20North%20America/202508171245_Race%202/GR%20Teams%20Championship.csv
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/07_Barber%20Motorsports%20Park/48_TGRNA%20GR%20Cup%20North%20America/202509061340_Race%201/03_Provisional%20Results_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/07_Barber%20Motorsports%20Park/48_TGRNA%20GR%20Cup%20North%20America/202509061340_Race%201/05_Provisional%20Results%20by%20Class_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/07_Barber%20Motorsports%20Park/48_TGRNA%20GR%20Cup%20North%20America/202509061340_Race%201/23_AnalysisEnduranceWithSections_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/07_Barber%20Motorsports%20Park/48_TGRNA%20GR%20Cup%20North%20America/202509061340_Race%201/26_Weather_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/07_Barber%20Motorsports%20Park/48_TGRNA%20GR%20Cup%20North%20America/202509061340_Race%201/99_Best%2010%20Laps%20By%20Driver_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/07_Barber%20Motorsports%20Park/48_TGRNA%20GR%20Cup%20North%20America/202509071005_Race%202/03_Provisional%20Results_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/07_Barber%20Motorsports%20Park/48_TGRNA%20GR%20Cup%20North%20America/202509071005_Race%202/03_Results%20GR%20Cup%20Race%201%20Official.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/07_Barber%20Motorsports%20Park/48_TGRNA%20GR%20Cup%20North%20America/202509071005_Race%202/03_Results%20GR%20Cup%20Race%202%20Official.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/07_Barber%20Motorsports%20Park/48_TGRNA%20GR%20Cup%20North%20America/202509071005_Race%202/05_Provisional%20Results%20by%20Class_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/07_Barber%20Motorsports%20Park/48_TGRNA%20GR%20Cup%20North%20America/202509071005_Race%202/05_Results%20by%20Class%20GR%20Cup%20Race%201%20Official.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/07_Barber%20Motorsports%20Park/48_TGRNA%20GR%20Cup%20North%20America/202509071005_Race%202/05_Results%20by%20Class%20GR%20Cup%20Race%202%20Official.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/07_Barber%20Motorsports%20Park/48_TGRNA%20GR%20Cup%20North%20America/202509071005_Race%202/23_AnalysisEnduranceWithSections_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/07_Barber%20Motorsports%20Park/48_TGRNA%20GR%20Cup%20North%20America/202509071005_Race%202/26_Weather_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/07_Barber%20Motorsports%20Park/48_TGRNA%20GR%20Cup%20North%20America/202509071005_Race%202/99_Best%2010%20Laps%20By%20Driver_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/07_Barber%20Motorsports%20Park/48_TGRNA%20GR%20Cup%20North%20America/202509071005_Race%202/GR%20Drivers%20Championship.csv
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/07_Barber%20Motorsports%20Park/48_TGRNA%20GR%20Cup%20North%20America/202509071005_Race%202/GR%20Teams%20Championship.csv
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/08_Indianapolis%20Motor%20Speedway%20RC/52_TGRNA%20GR%20Cup%20North%20America/202510180850_Race%201/03_Provisional%20Results_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/08_Indianapolis%20Motor%20Speedway%20RC/52_TGRNA%20GR%20Cup%20North%20America/202510180850_Race%201/05_Provisional%20Results%20by%20Class_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/08_Indianapolis%20Motor%20Speedway%20RC/52_TGRNA%20GR%20Cup%20North%20America/202510180850_Race%201/23_AnalysisEnduranceWithSections_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/08_Indianapolis%20Motor%20Speedway%20RC/52_TGRNA%20GR%20Cup%20North%20America/202510180850_Race%201/26_Weather_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/08_Indianapolis%20Motor%20Speedway%20RC/52_TGRNA%20GR%20Cup%20North%20America/202510180850_Race%201/99_Best%2010%20Laps%20By%20Driver_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/08_Indianapolis%20Motor%20Speedway%20RC/52_TGRNA%20GR%20Cup%20North%20America/202510191105_Race%202/03_GR%20Cup%20Race%201%20Official%20Results.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/08_Indianapolis%20Motor%20Speedway%20RC/52_TGRNA%20GR%20Cup%20North%20America/202510191105_Race%202/03_GR%20Cup%20Race%202%20Official%20Results.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/08_Indianapolis%20Motor%20Speedway%20RC/52_TGRNA%20GR%20Cup%20North%20America/202510191105_Race%202/03_Provisional%20Results_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/08_Indianapolis%20Motor%20Speedway%20RC/52_TGRNA%20GR%20Cup%20North%20America/202510191105_Race%202/05_GR%20Cup%20Race%201%20Official%20Results%20by%20Class.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/08_Indianapolis%20Motor%20Speedway%20RC/52_TGRNA%20GR%20Cup%20North%20America/202510191105_Race%202/05_GR%20Cup%20Race%202%20Official%20Results%20by%20Class.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/08_Indianapolis%20Motor%20Speedway%20RC/52_TGRNA%20GR%20Cup%20North%20America/202510191105_Race%202/05_Provisionals%20Results%20by%20Class_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/08_Indianapolis%20Motor%20Speedway%20RC/52_TGRNA%20GR%20Cup%20North%20America/202510191105_Race%202/23_AnalysisEnduranceWithSections_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/08_Indianapolis%20Motor%20Speedway%20RC/52_TGRNA%20GR%20Cup%20North%20America/202510191105_Race%202/26_Weather_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/08_Indianapolis%20Motor%20Speedway%20RC/52_TGRNA%20GR%20Cup%20North%20America/202510191105_Race%202/99_Best%2010%20Laps%20By%20Driver_Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/08_Indianapolis%20Motor%20Speedway%20RC/52_TGRNA%20GR%20Cup%20North%20America/202510191105_Race%202/GR%20Drivers%20Championship-1.csv
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/08_Indianapolis%20Motor%20Speedway%20RC/52_TGRNA%20GR%20Cup%20North%20America/202510191105_Race%202/GR%20Legends%20Cup%20Championship-1.csv
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/08_Indianapolis%20Motor%20Speedway%20RC/52_TGRNA%20GR%20Cup%20North%20America/202510191105_Race%202/GR%20Teams%20Championship.csv

# %% [markdown]
# ### Rough

# %%
filtered_df.iloc[0,-1]
# Out:
# 'http://usac.alkamelna.com/Results/06_SRO/25_2025/08_Indianapolis%20Motor%20Speedway%20RC/52_TGRNA%20GR%20Cup%20North%20America/202510180850_Race%201/03_Provisional%20Results_Race%201.CSV'

# %%
filtered_df['Sonoma Raceway'].apply(lambda url: download_file(url,out_dir = 'Sonoma Raceway'))
# Out:
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/01_Sonoma%20Raceway/06_TGRNA%20GR%20Cup%20North%20America/202503291405_Race%201/03_Results.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/01_Sonoma%20Raceway/06_TGRNA%20GR%20Cup%20North%20America/202503291405_Race%201/03_Results_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/01_Sonoma%20Raceway/06_TGRNA%20GR%20Cup%20North%20America/202503291405_Race%201/05_Results%20by%20Class_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/01_Sonoma%20Raceway/06_TGRNA%20GR%20Cup%20North%20America/202503291405_Race%201/23_AnalysisEnduranceWithSections_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/01_Sonoma%20Raceway/06_TGRNA%20GR%20Cup%20North%20America/202503291405_Race%201/26_Weather_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/01_Sonoma%20Raceway/06_TGRNA%20GR%20Cup%20North%20America/202503291405_Race%201/99_Best%2010%20Laps%20By%20Driver_Race%201.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/01_Sonoma%20Raceway/06_TGRNA%20GR%20Cup%20North%20America/202503301255_%20Race%202/03_Provisional_Results_%20Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/01_Sonoma%20Raceway/06_TGRNA%20GR%20Cup%20North%20America/202503301255_%20Race%202/03_Results.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/01_Sonoma%20Raceway/06_TGRNA%20GR%20Cup%20North%20America/202503301255_%20Race%202/05_Provisional_Results%20by%20Class_%20Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/01_Sonoma%20Raceway/06_TGRNA%20GR%20Cup%20North%20America/202503301255_%20Race%202/23_AnalysisEnduranceWithSections_%20Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/01_Sonoma%20Raceway/06_TGRNA%20GR%20Cup%20North%20America/202503301255_%20Race%202/26_Weather_%20Race%202.CSV
# fileurl:  http://usac.alkamelna.com/Results/06_SRO/25_2025/01_Sonoma%20Raceway/06_TGRNA%20GR%20Cup%20North%20America/202503301255_%20Race%202/99_Best%2010%20Laps%20By%20Driver_%20Race%202.CSV
# 30                                                   NaN
# 31                                                   NaN
# 32                                                   NaN
# 33                                                   NaN
# 34                                                   NaN
#                              ...
# 208         ..\data\Sonoma Raceway\RACE 2\03_Results.CSV
# 209    ..\data\Sonoma Raceway\RACE 2\05_Provisional_R...
# 210    ..\data\Sonoma Raceway\RACE 2\23_AnalysisEndur...
# 211    ..\data\Sonoma Raceway\RACE 2\26_Weather_%20Ra...
# 212    ..\data\Sonoma Raceway\RACE 2\99_Best%2010%20L...
# Name: Sonoma Raceway, Length: 83, dtype: str

# %%
def fixing_filename(base_folder):
    for root, dirs, files in os.walk(base_folder):
        for filename in files:
            if "%20" in filename:
                old_path = os.path.join(root, filename)
                new_filename = filename.replace("%20", "_")
                new_path = os.path.join(root, new_filename)

                os.rename(old_path, new_path)
    print('Fixing Complete')

# %%
fixing_filename('../data')
# Out:
# Fixing Complete
